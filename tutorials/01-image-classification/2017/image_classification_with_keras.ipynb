# %% [markdown]
# ## I - TRAIN AN IMAGE CLASSIFIER USING KERAS

# %% [markdown]
# __This tutorial is based on Keras documentaion__
#
#  __Note__ : you need to install: scipy, numpy, PIL, matplotlib, keras

# %%
#DO SOME IMPORTS
import os
import os.path as op
import keras
from os.path import expanduser
from keras.preprocessing import image
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Convolution2D, MaxPooling2D, Conv2D
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
from keras import backend as K
K.set_image_dim_ordering('th')
from keras.utils import plot_model
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
from PIL import Image
from keras.utils import plot_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import cv2

# %%
root_dir = expanduser(".")
model_root_dir = op.join (root_dir,"models" )
model_path = op.join (model_root_dir, "final")
checkpoint_path = op.join (model_root_dir, "model.{epoch:02d}-{loss:.2f}.hdf5")

# %%
original_image = cv2.imread('data/train/dogs/dog.1.jpg')
#show an image
plt.imshow(original_image)
plt.show()
print(original_image.shape)

reshaped_image = cv2.resize(original_image,(150,150))
#save the reshaped image as a file
cv2.imwrite('data/reshaped_image.png',reshaped_image)

dog = cv2.imread('data/reshaped_image.png')
plt.imshow(dog)
plt.show()
print (reshaped_image.shape)
# Out:
# (499, 327, 3)
# (150, 150, 3)

# %% [markdown]
# ### LOAD DATA : https://www.kaggle.com/tongpython/cat-and-dog

# %%
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        #rescale=1./255,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest')

img = load_img('data/train/dogs/dog.1.jpg')  # this is a PIL image
x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
print(x.shape)
x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)


# the .flow() command below generates batches of randomly transformed images
# and saves the results to the `preview/` directory
i = 0
for batch in datagen.flow(x, batch_size=1,
                          save_to_dir='data/preview', save_prefix='0', save_format='jpeg'):
    i += 1
    if i > 20:
        break  # otherwise the generator would loop indefinitely
# Out:
# (3, 499, 327)

# %% [markdown]
# ### BUILD MODEL

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(3, 150, 150)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
plot_model(model, to_file='model1.png', show_shapes=True, show_layer_names=True) 
img = load_img('model1.png')
img.show()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 148, 148)      896
# _________________________________________________________________
# activation_153 (Activation)  (None, 32, 148, 148)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 74, 74)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 72, 72)        9248
# _________________________________________________________________
# activation_154 (Activation)  (None, 32, 72, 72)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 32, 36, 36)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 64, 34, 34)        18496
# _________________________________________________________________
# activation_155 (Activation)  (None, 64, 34, 34)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 64, 17, 17)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_156 (Activation)  (None, 64)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_157 (Activation)  (None, 1)                 0
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### NETWOK PARAMETERS

# %%
batch_size = 128 #512
nb_train_samples = 8005
nb_validation_samples = 2023
nb_epoch = 200

# %%
# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
        rescale=1./255, # normalize pixel values to [0,1]
        shear_range=0.2,# randomly applies shearing transformation
        zoom_range=0.2,# randomly applies shearing transformation
        horizontal_flip=True)# randomly flip the images

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# this is a generator that will read pictures found in
# subfolers of 'data/train', and indefinitely generate
# batches of augmented image data
train_generator = train_datagen.flow_from_directory(
        'data/train',  # this is the target directory
        target_size=(150, 150),  # all images will be resized to 150x150
        batch_size=batch_size,
        class_mode='binary')  # since we use binary_crossentropy loss, we need binary labels

# this is a similar generator, for validation data
validation_generator = test_datagen.flow_from_directory(
        'data/validation',
        target_size=(150, 150),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %% [markdown]
# ### TRAIN MODEL and SAVE MODEL

# %%
#Comment out this part to train your model
#history = model.fit_generator(
        #train_generator,
        #steps_per_epoch=8005 // batch_size,
        #epochs=nb_epoch,
        #validation_data=validation_generator,
        #validation_steps=2023 // batch_size,
        #callbacks = [ModelCheckpoint(checkpoint_path)])
#model.save(model_path)  
#model.save(model_path)#weights_path)
# Out:
# Epoch 1/200
# 62/62 [==============================] - 49s 788ms/step - loss: 0.6767 - acc: 0.5784 - val_loss: 0.6196 - val_acc: 0.6297
# Epoch 2/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.6249 - acc: 0.6581 - val_loss: 0.5687 - val_acc: 0.7003
# Epoch 3/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.5958 - acc: 0.6878 - val_loss: 0.5443 - val_acc: 0.7230
# Epoch 4/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.5770 - acc: 0.6993 - val_loss: 0.5621 - val_acc: 0.7124
# Epoch 5/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.5449 - acc: 0.7232 - val_loss: 0.5111 - val_acc: 0.7478
# Epoch 6/200
# 62/62 [==============================] - 47s 755ms/step - loss: 0.5265 - acc: 0.7402 - val_loss: 0.4937 - val_acc: 0.7567
# Epoch 7/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.5061 - acc: 0.7546 - val_loss: 0.4675 - val_acc: 0.7836
# Epoch 8/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.4943 - acc: 0.7618 - val_loss: 0.4891 - val_acc: 0.7478
# Epoch 9/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.4844 - acc: 0.7658 - val_loss: 0.5380 - val_acc: 0.7367
# Epoch 10/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.4660 - acc: 0.7760 - val_loss: 0.4385 - val_acc: 0.7968
# Epoch 11/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.4571 - acc: 0.7905 - val_loss: 0.4519 - val_acc: 0.7900
# Epoch 12/200
# 62/62 [==============================] - 46s 746ms/step - loss: 0.4382 - acc: 0.7941 - val_loss: 0.5237 - val_acc: 0.7435
# Epoch 13/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.4442 - acc: 0.7926 - val_loss: 0.4707 - val_acc: 0.7794
# Epoch 14/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.4244 - acc: 0.8054 - val_loss: 0.4109 - val_acc: 0.8069
# Epoch 15/200
# 62/62 [==============================] - 47s 760ms/step - loss: 0.4150 - acc: 0.8117 - val_loss: 0.4620 - val_acc: 0.7937
# Epoch 16/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.4146 - acc: 0.8119 - val_loss: 0.4377 - val_acc: 0.8116
# Epoch 17/200
# 62/62 [==============================] - 46s 746ms/step - loss: 0.3842 - acc: 0.8279 - val_loss: 0.4406 - val_acc: 0.7958
# Epoch 18/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.3864 - acc: 0.8229 - val_loss: 0.4148 - val_acc: 0.8211
# Epoch 19/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.3840 - acc: 0.8319 - val_loss: 0.4199 - val_acc: 0.8090
# Epoch 20/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.3798 - acc: 0.8300 - val_loss: 0.4182 - val_acc: 0.8174
# Epoch 21/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.3613 - acc: 0.8391 - val_loss: 0.4548 - val_acc: 0.7842
# Epoch 22/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.3550 - acc: 0.8468 - val_loss: 0.4027 - val_acc: 0.8227
# Epoch 23/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.3569 - acc: 0.8410 - val_loss: 0.3955 - val_acc: 0.8280
# Epoch 24/200
# 62/62 [==============================] - 47s 760ms/step - loss: 0.3444 - acc: 0.8515 - val_loss: 0.3986 - val_acc: 0.8311
# Epoch 25/200
# 62/62 [==============================] - 46s 739ms/step - loss: 0.3413 - acc: 0.8569 - val_loss: 0.4065 - val_acc: 0.8380
# Epoch 26/200
# 62/62 [==============================] - 46s 750ms/step - loss: 0.3223 - acc: 0.8619 - val_loss: 0.3644 - val_acc: 0.8480
# Epoch 27/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.3184 - acc: 0.8630 - val_loss: 0.4227 - val_acc: 0.8137
# Epoch 28/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.3228 - acc: 0.8613 - val_loss: 0.3747 - val_acc: 0.8491
# Epoch 29/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.3171 - acc: 0.8642 - val_loss: 0.4851 - val_acc: 0.7921
# Epoch 30/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.3057 - acc: 0.8722 - val_loss: 0.4191 - val_acc: 0.8391
# Epoch 31/200
# 62/62 [==============================] - 47s 757ms/step - loss: 0.3091 - acc: 0.8728 - val_loss: 0.4110 - val_acc: 0.8232
# Epoch 32/200
# 62/62 [==============================] - 47s 752ms/step - loss: 0.2912 - acc: 0.8754 - val_loss: 0.4159 - val_acc: 0.8380
# Epoch 33/200
# 62/62 [==============================] - 47s 753ms/step - loss: 0.2994 - acc: 0.8726 - val_loss: 0.3533 - val_acc: 0.8547
# Epoch 34/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2885 - acc: 0.8808 - val_loss: 0.3793 - val_acc: 0.8512
# Epoch 35/200
# 62/62 [==============================] - 48s 771ms/step - loss: 0.2900 - acc: 0.8765 - val_loss: 0.4129 - val_acc: 0.8401
# Epoch 36/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2833 - acc: 0.8796 - val_loss: 0.3933 - val_acc: 0.8507
# Epoch 37/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.2650 - acc: 0.8921 - val_loss: 0.3755 - val_acc: 0.8575
# Epoch 38/200
# 62/62 [==============================] - 46s 744ms/step - loss: 0.2691 - acc: 0.8896 - val_loss: 0.3841 - val_acc: 0.8586
# Epoch 39/200
# 62/62 [==============================] - 46s 749ms/step - loss: 0.2696 - acc: 0.8858 - val_loss: 0.4289 - val_acc: 0.8301
# Epoch 40/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.2747 - acc: 0.8863 - val_loss: 0.3984 - val_acc: 0.8580
# Epoch 41/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2612 - acc: 0.8922 - val_loss: 0.3974 - val_acc: 0.8485
# Epoch 42/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2592 - acc: 0.8976 - val_loss: 0.4601 - val_acc: 0.8507
# Epoch 43/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2563 - acc: 0.8977 - val_loss: 0.3952 - val_acc: 0.8591
# Epoch 44/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.2478 - acc: 0.9013 - val_loss: 0.4049 - val_acc: 0.8475
# Epoch 45/200
# 62/62 [==============================] - 47s 755ms/step - loss: 0.2555 - acc: 0.8972 - val_loss: 0.3921 - val_acc: 0.8491
# Epoch 46/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.2457 - acc: 0.8971 - val_loss: 0.3835 - val_acc: 0.8459
# Epoch 47/200
# 62/62 [==============================] - 47s 753ms/step - loss: 0.2425 - acc: 0.8969 - val_loss: 0.3758 - val_acc: 0.8580
# Epoch 48/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2396 - acc: 0.9003 - val_loss: 0.3686 - val_acc: 0.8464
# Epoch 49/200
# 62/62 [==============================] - 48s 771ms/step - loss: 0.2342 - acc: 0.9038 - val_loss: 0.4363 - val_acc: 0.8490
# Epoch 50/200
# 62/62 [==============================] - 48s 771ms/step - loss: 0.2410 - acc: 0.9035 - val_loss: 0.3924 - val_acc: 0.8686
# Epoch 51/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2340 - acc: 0.9044 - val_loss: 0.4687 - val_acc: 0.8475
# Epoch 52/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2313 - acc: 0.9047 - val_loss: 0.4229 - val_acc: 0.8385
# Epoch 53/200
# 62/62 [==============================] - 47s 750ms/step - loss: 0.2348 - acc: 0.9065 - val_loss: 0.3734 - val_acc: 0.8670
# Epoch 54/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2303 - acc: 0.9099 - val_loss: 0.4012 - val_acc: 0.8454
# Epoch 55/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2212 - acc: 0.9091 - val_loss: 0.4340 - val_acc: 0.8538
# Epoch 56/200
# 62/62 [==============================] - 48s 771ms/step - loss: 0.2241 - acc: 0.9090 - val_loss: 0.4616 - val_acc: 0.8617
# Epoch 57/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2258 - acc: 0.9144 - val_loss: 0.4259 - val_acc: 0.8723
# Epoch 58/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2191 - acc: 0.9104 - val_loss: 0.3809 - val_acc: 0.8565
# Epoch 59/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2276 - acc: 0.9087 - val_loss: 0.4726 - val_acc: 0.8565
# Epoch 60/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2269 - acc: 0.9119 - val_loss: 0.4395 - val_acc: 0.8623
# Epoch 61/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.2255 - acc: 0.9118 - val_loss: 0.4039 - val_acc: 0.8570
# Epoch 62/200
# 62/62 [==============================] - 46s 746ms/step - loss: 0.2252 - acc: 0.9126 - val_loss: 0.4176 - val_acc: 0.8670
# Epoch 63/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.2065 - acc: 0.9156 - val_loss: 0.5428 - val_acc: 0.8491
# Epoch 64/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2153 - acc: 0.9144 - val_loss: 0.4611 - val_acc: 0.8628
# Epoch 65/200
# 62/62 [==============================] - 47s 760ms/step - loss: 0.2206 - acc: 0.9132 - val_loss: 0.4410 - val_acc: 0.8641
# Epoch 66/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2102 - acc: 0.9172 - val_loss: 0.4890 - val_acc: 0.8586
# Epoch 67/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2060 - acc: 0.9218 - val_loss: 0.4718 - val_acc: 0.8412
# Epoch 68/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2024 - acc: 0.9215 - val_loss: 0.4057 - val_acc: 0.8691
# Epoch 69/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2044 - acc: 0.9184 - val_loss: 0.4667 - val_acc: 0.8522
# Epoch 70/200
# 62/62 [==============================] - 46s 738ms/step - loss: 0.2114 - acc: 0.9196 - val_loss: 0.3830 - val_acc: 0.8633
# Epoch 71/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2017 - acc: 0.9163 - val_loss: 0.3870 - val_acc: 0.8570
# Epoch 72/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2038 - acc: 0.9190 - val_loss: 0.4698 - val_acc: 0.8559
# Epoch 73/200
# 62/62 [==============================] - 47s 754ms/step - loss: 0.1978 - acc: 0.9203 - val_loss: 0.4114 - val_acc: 0.8660
# Epoch 74/200
# 62/62 [==============================] - 46s 743ms/step - loss: 0.1952 - acc: 0.9257 - val_loss: 0.4559 - val_acc: 0.8607
# Epoch 75/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2091 - acc: 0.9222 - val_loss: 0.4529 - val_acc: 0.8628
# Epoch 76/200
# 62/62 [==============================] - 48s 773ms/step - loss: 0.1995 - acc: 0.9246 - val_loss: 0.4612 - val_acc: 0.8839
# Epoch 77/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2071 - acc: 0.9227 - val_loss: 0.4554 - val_acc: 0.8675
# Epoch 78/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2048 - acc: 0.9159 - val_loss: 0.5207 - val_acc: 0.8259
# Epoch 79/200
# 62/62 [==============================] - 46s 746ms/step - loss: 0.1936 - acc: 0.9270 - val_loss: 0.6754 - val_acc: 0.8079
# Epoch 80/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.2046 - acc: 0.9246 - val_loss: 0.5544 - val_acc: 0.8517
# Epoch 81/200
# 62/62 [==============================] - 47s 760ms/step - loss: 0.1923 - acc: 0.9260 - val_loss: 0.5363 - val_acc: 0.8469
# Epoch 82/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2186 - acc: 0.9148 - val_loss: 0.4246 - val_acc: 0.8760
# Epoch 83/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.1927 - acc: 0.9254 - val_loss: 0.5464 - val_acc: 0.8575
# Epoch 84/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.1885 - acc: 0.9299 - val_loss: 0.4653 - val_acc: 0.8633
# Epoch 85/200
# 62/62 [==============================] - 47s 757ms/step - loss: 0.1969 - acc: 0.9186 - val_loss: 0.4380 - val_acc: 0.8660
# Epoch 86/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2107 - acc: 0.9195 - val_loss: 0.5746 - val_acc: 0.8718
# Epoch 87/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.2055 - acc: 0.9207 - val_loss: 0.3908 - val_acc: 0.8602
# Epoch 88/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2020 - acc: 0.9218 - val_loss: 0.6721 - val_acc: 0.8243
# Epoch 89/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.1913 - acc: 0.9245 - val_loss: 0.8166 - val_acc: 0.8660
# Epoch 90/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2051 - acc: 0.9208 - val_loss: 0.7134 - val_acc: 0.8222
# Epoch 91/200
# 62/62 [==============================] - 48s 773ms/step - loss: 0.1915 - acc: 0.9292 - val_loss: 0.4610 - val_acc: 0.8586
# Epoch 92/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2134 - acc: 0.9196 - val_loss: 0.4411 - val_acc: 0.8507
# Epoch 93/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2071 - acc: 0.9169 - val_loss: 0.4699 - val_acc: 0.8734
# Epoch 94/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.1977 - acc: 0.9255 - val_loss: 0.3589 - val_acc: 0.8602
# Epoch 95/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2048 - acc: 0.9181 - val_loss: 0.5378 - val_acc: 0.8670
# Epoch 96/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.2026 - acc: 0.9253 - val_loss: 0.4364 - val_acc: 0.8512
# Epoch 97/200
# 62/62 [==============================] - 46s 746ms/step - loss: 0.2044 - acc: 0.9199 - val_loss: 0.7241 - val_acc: 0.8526
# Epoch 98/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.1955 - acc: 0.9279 - val_loss: 0.5588 - val_acc: 0.8770
# Epoch 99/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.1945 - acc: 0.9291 - val_loss: 0.5568 - val_acc: 0.8681
# Epoch 100/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2077 - acc: 0.9158 - val_loss: 0.4123 - val_acc: 0.8786
# Epoch 101/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.1903 - acc: 0.9257 - val_loss: 0.5297 - val_acc: 0.8660
# Epoch 102/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2122 - acc: 0.9206 - val_loss: 0.4195 - val_acc: 0.8776
# Epoch 103/200
# 62/62 [==============================] - 46s 739ms/step - loss: 0.2130 - acc: 0.9188 - val_loss: 0.4576 - val_acc: 0.8697
# Epoch 104/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2266 - acc: 0.9132 - val_loss: 0.4426 - val_acc: 0.8269
# Epoch 105/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2204 - acc: 0.9147 - val_loss: 0.4010 - val_acc: 0.8602
# Epoch 106/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.1961 - acc: 0.9255 - val_loss: 0.5506 - val_acc: 0.8797
# Epoch 107/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2032 - acc: 0.9266 - val_loss: 0.4125 - val_acc: 0.8654
# Epoch 108/200
# 62/62 [==============================] - 47s 752ms/step - loss: 0.1998 - acc: 0.9252 - val_loss: 0.4621 - val_acc: 0.8654
# Epoch 109/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2229 - acc: 0.9157 - val_loss: 0.5879 - val_acc: 0.8412
# Epoch 110/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2109 - acc: 0.9227 - val_loss: 0.5368 - val_acc: 0.8792
# Epoch 111/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2206 - acc: 0.9149 - val_loss: 0.4148 - val_acc: 0.8311
# Epoch 112/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.2196 - acc: 0.9151 - val_loss: 0.3831 - val_acc: 0.8712
# Epoch 113/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.1954 - acc: 0.9268 - val_loss: 0.5526 - val_acc: 0.8266
# Epoch 114/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2118 - acc: 0.9219 - val_loss: 0.5516 - val_acc: 0.8317
# Epoch 115/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2218 - acc: 0.9126 - val_loss: 0.5660 - val_acc: 0.8792
# Epoch 116/200
# 62/62 [==============================] - 47s 752ms/step - loss: 0.2091 - acc: 0.9198 - val_loss: 0.8054 - val_acc: 0.8422
# Epoch 117/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2094 - acc: 0.9200 - val_loss: 0.4260 - val_acc: 0.8675
# Epoch 118/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.2087 - acc: 0.9217 - val_loss: 0.5229 - val_acc: 0.8828
# Epoch 119/200
# 62/62 [==============================] - 47s 752ms/step - loss: 0.2178 - acc: 0.9145 - val_loss: 0.6707 - val_acc: 0.8111
# Epoch 120/200
# 62/62 [==============================] - 46s 748ms/step - loss: 0.2187 - acc: 0.9139 - val_loss: 0.4418 - val_acc: 0.8739
# Epoch 121/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.2166 - acc: 0.9196 - val_loss: 0.4610 - val_acc: 0.7662
# Epoch 122/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2317 - acc: 0.9093 - val_loss: 0.4373 - val_acc: 0.8570
# Epoch 123/200
# 62/62 [==============================] - 46s 742ms/step - loss: 0.2384 - acc: 0.9097 - val_loss: 0.8181 - val_acc: 0.8586
# Epoch 124/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2380 - acc: 0.9076 - val_loss: 0.6211 - val_acc: 0.8670
# Epoch 125/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2190 - acc: 0.9192 - val_loss: 0.5856 - val_acc: 0.8480
# Epoch 126/200
# 62/62 [==============================] - 47s 757ms/step - loss: 0.2202 - acc: 0.9174 - val_loss: 0.5529 - val_acc: 0.8839
# Epoch 127/200
# 62/62 [==============================] - 47s 760ms/step - loss: 0.2316 - acc: 0.9081 - val_loss: 0.4848 - val_acc: 0.8475
# Epoch 128/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2307 - acc: 0.9094 - val_loss: 0.7147 - val_acc: 0.8332
# Epoch 129/200
# 62/62 [==============================] - 48s 773ms/step - loss: 0.2285 - acc: 0.9111 - val_loss: 0.5426 - val_acc: 0.8703
# Epoch 130/200
# 62/62 [==============================] - 47s 752ms/step - loss: 0.2347 - acc: 0.9070 - val_loss: 0.5603 - val_acc: 0.8660
# Epoch 131/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.2153 - acc: 0.9171 - val_loss: 0.8825 - val_acc: 0.8084
# Epoch 132/200
# 62/62 [==============================] - 47s 757ms/step - loss: 0.2543 - acc: 0.9046 - val_loss: 0.5172 - val_acc: 0.8485
# Epoch 133/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2266 - acc: 0.9123 - val_loss: 0.6256 - val_acc: 0.8697
# Epoch 134/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2287 - acc: 0.9120 - val_loss: 0.4203 - val_acc: 0.8385
# Epoch 135/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2248 - acc: 0.9139 - val_loss: 0.4454 - val_acc: 0.8586
# Epoch 136/200
# 62/62 [==============================] - 45s 733ms/step - loss: 0.2413 - acc: 0.9089 - val_loss: 0.4639 - val_acc: 0.8470
# Epoch 137/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2407 - acc: 0.9052 - val_loss: 0.3728 - val_acc: 0.8496
# Epoch 138/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2431 - acc: 0.9083 - val_loss: 0.4748 - val_acc: 0.8660
# Epoch 139/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2328 - acc: 0.9136 - val_loss: 0.5134 - val_acc: 0.8681
# Epoch 140/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.2431 - acc: 0.9059 - val_loss: 0.6010 - val_acc: 0.8697
# Epoch 141/200
# 62/62 [==============================] - 46s 749ms/step - loss: 0.2457 - acc: 0.9075 - val_loss: 0.4838 - val_acc: 0.8649
# Epoch 142/200
# 62/62 [==============================] - 46s 742ms/step - loss: 0.2363 - acc: 0.9083 - val_loss: 0.5785 - val_acc: 0.8401
# Epoch 143/200
# 62/62 [==============================] - 47s 760ms/step - loss: 0.2419 - acc: 0.9035 - val_loss: 0.5286 - val_acc: 0.8602
# Epoch 144/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2221 - acc: 0.9149 - val_loss: 0.5317 - val_acc: 0.8781
# Epoch 145/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2237 - acc: 0.9127 - val_loss: 0.4631 - val_acc: 0.8500
# Epoch 146/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.2189 - acc: 0.9113 - val_loss: 0.4096 - val_acc: 0.8607
# Epoch 147/200
# 62/62 [==============================] - 47s 750ms/step - loss: 0.2438 - acc: 0.9078 - val_loss: 0.7136 - val_acc: 0.8723
# Epoch 148/200
# 62/62 [==============================] - 47s 753ms/step - loss: 0.2318 - acc: 0.9071 - val_loss: 0.4537 - val_acc: 0.8860
# Epoch 149/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2470 - acc: 0.9002 - val_loss: 0.5916 - val_acc: 0.8639
# Epoch 150/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2363 - acc: 0.9100 - val_loss: 0.3475 - val_acc: 0.8887
# Epoch 151/200
# 62/62 [==============================] - 47s 755ms/step - loss: 0.2644 - acc: 0.8954 - val_loss: 0.5163 - val_acc: 0.8660
# Epoch 152/200
# 62/62 [==============================] - 46s 747ms/step - loss: 0.2303 - acc: 0.9131 - val_loss: 0.5340 - val_acc: 0.8501
# Epoch 153/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.2524 - acc: 0.8978 - val_loss: 0.5248 - val_acc: 0.8818
# Epoch 154/200
# 62/62 [==============================] - 45s 731ms/step - loss: 0.2337 - acc: 0.9092 - val_loss: 0.6043 - val_acc: 0.8554
# Epoch 155/200
# 62/62 [==============================] - 47s 755ms/step - loss: 0.3127 - acc: 0.8811 - val_loss: 0.5411 - val_acc: 0.8148
# Epoch 156/200
# 62/62 [==============================] - 47s 753ms/step - loss: 0.2386 - acc: 0.9065 - val_loss: 0.5178 - val_acc: 0.8470
# Epoch 157/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2586 - acc: 0.8972 - val_loss: 0.4143 - val_acc: 0.8454
# Epoch 158/200
# 62/62 [==============================] - 47s 757ms/step - loss: 0.2582 - acc: 0.9028 - val_loss: 0.4049 - val_acc: 0.8760
# Epoch 159/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2709 - acc: 0.8904 - val_loss: 0.3455 - val_acc: 0.8612
# Epoch 160/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2324 - acc: 0.9102 - val_loss: 0.6174 - val_acc: 0.8739
# Epoch 161/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.2473 - acc: 0.9075 - val_loss: 0.4224 - val_acc: 0.8219
# Epoch 162/200
# 62/62 [==============================] - 46s 745ms/step - loss: 0.2267 - acc: 0.9080 - val_loss: 0.5139 - val_acc: 0.8364
# Epoch 163/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.2446 - acc: 0.9020 - val_loss: 0.4137 - val_acc: 0.8364
# Epoch 164/200
# 62/62 [==============================] - 47s 755ms/step - loss: 0.2613 - acc: 0.9012 - val_loss: 0.5206 - val_acc: 0.8765
# Epoch 165/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2329 - acc: 0.9108 - val_loss: 0.4162 - val_acc: 0.8311
# Epoch 166/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.2434 - acc: 0.9052 - val_loss: 0.3869 - val_acc: 0.8269
# Epoch 167/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.2465 - acc: 0.9010 - val_loss: 0.5296 - val_acc: 0.8770
# Epoch 168/200
# 62/62 [==============================] - 48s 769ms/step - loss: 0.2410 - acc: 0.9066 - val_loss: 0.4792 - val_acc: 0.8802
# Epoch 169/200
# 62/62 [==============================] - 48s 771ms/step - loss: 0.2642 - acc: 0.8983 - val_loss: 0.5045 - val_acc: 0.8712
# Epoch 170/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2470 - acc: 0.9058 - val_loss: 0.4157 - val_acc: 0.8734
# Epoch 171/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.2590 - acc: 0.8941 - val_loss: 0.5247 - val_acc: 0.8617
# Epoch 172/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2738 - acc: 0.8913 - val_loss: 0.5173 - val_acc: 0.8617
# Epoch 173/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2431 - acc: 0.9064 - val_loss: 0.4015 - val_acc: 0.8776
# Epoch 174/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.2430 - acc: 0.9043 - val_loss: 0.7120 - val_acc: 0.8670
# Epoch 175/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2282 - acc: 0.9155 - val_loss: 0.4684 - val_acc: 0.8343
# Epoch 176/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2456 - acc: 0.9058 - val_loss: 0.5305 - val_acc: 0.8718
# Epoch 177/200
# 62/62 [==============================] - 46s 742ms/step - loss: 0.2831 - acc: 0.8894 - val_loss: 0.6742 - val_acc: 0.8635
# Epoch 178/200
# 62/62 [==============================] - 47s 765ms/step - loss: 0.2556 - acc: 0.8961 - val_loss: 0.5284 - val_acc: 0.8760
# Epoch 179/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2545 - acc: 0.8980 - val_loss: 0.3483 - val_acc: 0.8697
# Epoch 180/200
# 62/62 [==============================] - 47s 751ms/step - loss: 0.2608 - acc: 0.8946 - val_loss: 0.4944 - val_acc: 0.8549
# Epoch 181/200
# 62/62 [==============================] - 46s 750ms/step - loss: 0.2341 - acc: 0.9125 - val_loss: 0.3959 - val_acc: 0.8755
# Epoch 182/200
# 62/62 [==============================] - 47s 758ms/step - loss: 0.2753 - acc: 0.8957 - val_loss: 0.5610 - val_acc: 0.7066
# Epoch 183/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2776 - acc: 0.8880 - val_loss: 0.7984 - val_acc: 0.8306
# Epoch 184/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2349 - acc: 0.9012 - val_loss: 0.5770 - val_acc: 0.8617
# Epoch 185/200
# 62/62 [==============================] - 48s 768ms/step - loss: 0.2445 - acc: 0.9062 - val_loss: 0.3972 - val_acc: 0.8100
# Epoch 186/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2454 - acc: 0.9075 - val_loss: 0.4282 - val_acc: 0.8739
# Epoch 187/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2466 - acc: 0.9037 - val_loss: 0.4765 - val_acc: 0.8517
# Epoch 188/200
# 62/62 [==============================] - 47s 755ms/step - loss: 0.2472 - acc: 0.9041 - val_loss: 0.4120 - val_acc: 0.8607
# Epoch 189/200
# 62/62 [==============================] - 47s 766ms/step - loss: 0.2554 - acc: 0.9026 - val_loss: 0.3977 - val_acc: 0.8517
# Epoch 190/200
# 62/62 [==============================] - 48s 767ms/step - loss: 0.2706 - acc: 0.9001 - val_loss: 0.3958 - val_acc: 0.8865
# Epoch 191/200
# 62/62 [==============================] - 47s 756ms/step - loss: 0.2299 - acc: 0.9104 - val_loss: 0.3815 - val_acc: 0.8412
# Epoch 192/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2798 - acc: 0.8872 - val_loss: 0.5548 - val_acc: 0.8559
# Epoch 193/200
# 62/62 [==============================] - 48s 770ms/step - loss: 0.2564 - acc: 0.9065 - val_loss: 0.9033 - val_acc: 0.8078
# Epoch 194/200
# 62/62 [==============================] - 47s 759ms/step - loss: 0.2629 - acc: 0.8932 - val_loss: 0.3658 - val_acc: 0.8734
# Epoch 195/200
# 62/62 [==============================] - 47s 764ms/step - loss: 0.2361 - acc: 0.9052 - val_loss: 0.5200 - val_acc: 0.8649
# Epoch 196/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2654 - acc: 0.8954 - val_loss: 0.5126 - val_acc: 0.8712
# Epoch 197/200
# 62/62 [==============================] - 47s 762ms/step - loss: 0.2727 - acc: 0.8970 - val_loss: 0.3889 - val_acc: 0.8649
# Epoch 198/200
# 62/62 [==============================] - 47s 763ms/step - loss: 0.2435 - acc: 0.9041 - val_loss: 0.4140 - val_acc: 0.8797
# Epoch 199/200
# 62/62 [==============================] - 47s 761ms/step - loss: 0.2908 - acc: 0.8899 - val_loss: 0.4582 - val_acc: 0.8755
# Epoch 200/200
# 62/62 [==============================] - 47s 757ms/step - loss: 0.2298 - acc: 0.9071 - val_loss: 0.4880 - val_acc: 0.8707

# %% [markdown]
# ### LOADING THE TRAINING MODEL

# %%
model.load_weights('./models/model.113-0.19.hdf5')

# %% [markdown]
# ### VISUALIZATION OF THE TRAINING HISTORY

# %%
#Comment out this part to visualize your model
##summarize history for accuracy
#plt.plot(history.history['acc'])
#plt.plot(history.history['val_acc'])
#plt.title('model accuracy')
#plt.ylabel('accuracy')
#plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
#plt.show()
#plt.savefig('accuracy.pdf')

# %%
#Comment out this part to visualize your model
#### summarize history for loss
#plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
#plt.title('model loss')
#plt.ylabel('loss')
#plt.xlabel('epoch')
#plt.legend(['train', 'test'], loc='upper left')
#plt.show()
#plt.savefig('loss.pdf')

# %% [markdown]
# ### Evaluating on test set

# %%
#Comment out this part to evaluate your model
#model.evaluate_generator(validation_generator, nb_validation_samples)
# Out:
# [0.5475189818062938, 0.8285249581846179]

# %% [markdown]
# ## II- Use pre-trained models

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet50 import ResNet50
from keras.applications.vgg16 import preprocess_input, decode_predictions

# %%
#vgg16
vgg16_feature_extract = VGG16(weights='imagenet', include_top=True)
plot_model(vgg16_feature_extract, to_file='vgg16.png', show_shapes=True, show_layer_names=True) 
img = load_img('vgg16.png')
img.show()
#vgg16_feature_extract.summary()

# %%
#vgg19
vgg19_feature_extract = VGG19(weights='imagenet', include_top=True)
plot_model(vgg19_feature_extract, to_file='vgg19.png', show_shapes=True, show_layer_names=True) 
img = load_img('vgg19.png')
img.show()
#vgg19_feature_extract.summary()

# %%
#resnet
resnet_feature_extract = ResNet50(weights='imagenet', include_top=True)
plot_model(resnet_feature_extract, to_file='resnet.png', show_shapes=True, show_layer_names=True) 
img = load_img('resnet.png')
img.show()
#resnet_feature_extract.summary()

# %% [markdown]
# ## CLASSIFY NEW IMAGES

# %%
#img = image.load_img('test.jpg', target_size=(224, 224))
img = image.load_img('cat.jpg', target_size=(224, 224))
#img = image.load_img('dog.jpg', target_size=(224, 224))

# %matplotlib inline
plt.imshow(img)

# %%
#img = image.load_img('elephant.jpg', target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
#preds = vgg16_feature_extract.predict(x)
#preds = vgg19_feature_extract.predict(x)
preds = resnet_feature_extract.predict(x)
decode_predictions(preds, top=10)[0]
# Out:
# [('n02123394', 'Persian_cat', 0.9997496),
#  ('n02086079', 'Pekinese', 7.307477e-05),
#  ('n02085782', 'Japanese_spaniel', 3.2587282e-05),
#  ('n02123045', 'tabby', 3.1419266e-05),
#  ('n02328150', 'Angora', 2.9787501e-05),
#  ('n02112137', 'chow', 1.4352736e-05),
#  ('n02112018', 'Pomeranian', 1.3843957e-05),
#  ('n02127052', 'lynx', 9.0863905e-06),
#  ('n02123159', 'tiger_cat', 8.089144e-06),
#  ('n02112706', 'Brabancon_griffon', 6.395916e-06)]
